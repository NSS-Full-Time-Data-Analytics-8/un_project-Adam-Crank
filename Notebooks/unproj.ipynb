# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# ## GDP_DF

# %%
gdp_df = pd.read_csv('../data/gdp_percapita.csv')
gdp_df.head(6)
# Out:
#   Country or Area  Year        Value  Value Footnotes
# 0     Afghanistan  2020  1970.560169              NaN
# 1     Afghanistan  2019  2065.036235              NaN
# 2     Afghanistan  2018  2033.804389              NaN
# 3     Afghanistan  2017  2058.400221              NaN
# 4     Afghanistan  2016  2057.067978              NaN
# 5     Afghanistan  2015  2068.265904              NaN

# %%
gdp_df.shape
# Out:
# (7176, 4)

# %% [markdown]
# gdp_df has 7176 rows and 4 columns

# %%
gdp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7176 entries, 0 to 7175
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Country or Area  7176 non-null   object
#  1   Year             7176 non-null   int64
#  2   Value            7176 non-null   float64
#  3   Value Footnotes  0 non-null      float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 224.4+ KB

# %%
gdp_df.tail(10)
# Out:
#      Country or Area  Year        Value  Value Footnotes
# 7166        Zimbabwe  1999  2872.714795              NaN
# 7167        Zimbabwe  1998  2915.052992              NaN
# 7168        Zimbabwe  1997  2856.118188              NaN
# 7169        Zimbabwe  1996  2808.558556              NaN
# 7170        Zimbabwe  1995  2573.993785              NaN
# 7171        Zimbabwe  1994  2603.927369              NaN
# 7172        Zimbabwe  1993  2420.092791              NaN
# 7173        Zimbabwe  1992  2437.152908              NaN
# 7174        Zimbabwe  1991  2733.696626              NaN
# 7175        Zimbabwe  1990  2652.129209              NaN

# %%
gdp_df = gdp_df.drop(columns = 'Value Footnotes')
gdp_df
# Out:
#      Country or Area  Year        Value
# 0        Afghanistan  2020  1970.560169
# 1        Afghanistan  2019  2065.036235
# 2        Afghanistan  2018  2033.804389
# 3        Afghanistan  2017  2058.400221
# 4        Afghanistan  2016  2057.067978
# ...              ...   ...          ...
# 7171        Zimbabwe  1994  2603.927369
# 7172        Zimbabwe  1993  2420.092791
# 7173        Zimbabwe  1992  2437.152908
# 7174        Zimbabwe  1991  2733.696626
# 7175        Zimbabwe  1990  2652.129209
#
# [7176 rows x 3 columns]

# %%
gdp_df.columns = ['Country', 'Year', 'GDP_Per_Capita']
gdp_df
# Out:
#           Country  Year  GDP_Per_Capita
# 0     Afghanistan  2020     1970.560169
# 1     Afghanistan  2019     2065.036235
# 2     Afghanistan  2018     2033.804389
# 3     Afghanistan  2017     2058.400221
# 4     Afghanistan  2016     2057.067978
# ...           ...   ...             ...
# 7171     Zimbabwe  1994     2603.927369
# 7172     Zimbabwe  1993     2420.092791
# 7173     Zimbabwe  1992     2437.152908
# 7174     Zimbabwe  1991     2733.696626
# 7175     Zimbabwe  1990     2652.129209
#
# [7176 rows x 3 columns]

# %% [markdown]
# ## INTERNET_DF

# %%
internet_df = pd.read_csv('../data/internet_use.csv', on_bad_lines='skip')
internet_df.head(6)
# Out:
#   Country or Area  Year     Value  Value Footnotes
# 0     Afghanistan  2014  6.390000              NaN
# 1     Afghanistan  2013  5.900000              NaN
# 2     Afghanistan  2012  5.454545              NaN
# 3     Afghanistan  2011  5.000000              NaN
# 4     Afghanistan  2010  4.000000              NaN
# 5     Afghanistan  2009  3.550000              NaN

# %%
internet_df.shape
# Out:
# (4675, 4)

# %% [markdown]
# internet_df has 4675 rows and 4 columns

# %%
internet_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4675 entries, 0 to 4674
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Country or Area  4675 non-null   object
#  1   Year             4675 non-null   object
#  2   Value            4495 non-null   float64
#  3   Value Footnotes  948 non-null    float64
# dtypes: float64(2), object(2)
# memory usage: 146.2+ KB

# %%
internet_df = internet_df.drop(range(4495,4675), axis = 0)
#Removing footnote values

# %%
internet_df['Year'] = pd.to_numeric(internet_df['Year'])

# %%
internet_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4495 entries, 0 to 4494
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Country or Area  4495 non-null   object
#  1   Year             4495 non-null   int64
#  2   Value            4495 non-null   float64
#  3   Value Footnotes  948 non-null    float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 140.6+ KB

# %%
internet_df.tail(10)
# Out:
#      Country or Area  Year     Value  Value Footnotes
# 4485        Zimbabwe  2002  3.994356              NaN
# 4486        Zimbabwe  2001  0.799846              NaN
# 4487        Zimbabwe  2000  0.401434              NaN
# 4488        Zimbabwe  1999  0.161676              NaN
# 4489        Zimbabwe  1998  0.081648              NaN
# 4490        Zimbabwe  1997  0.033080              NaN
# 4491        Zimbabwe  1996  0.016790              NaN
# 4492        Zimbabwe  1995  0.007684              NaN
# 4493        Zimbabwe  1994  0.001739              NaN
# 4494        Zimbabwe  1990  0.000000              NaN

# %%
internet_df = internet_df.drop(columns = 'Value Footnotes')
internet_df
# Out:
#      Country or Area  Year     Value
# 0        Afghanistan  2014  6.390000
# 1        Afghanistan  2013  5.900000
# 2        Afghanistan  2012  5.454545
# 3        Afghanistan  2011  5.000000
# 4        Afghanistan  2010  4.000000
# ...              ...   ...       ...
# 4490        Zimbabwe  1997  0.033080
# 4491        Zimbabwe  1996  0.016790
# 4492        Zimbabwe  1995  0.007684
# 4493        Zimbabwe  1994  0.001739
# 4494        Zimbabwe  1990  0.000000
#
# [4495 rows x 3 columns]

# %%
internet_df.columns = ['Country', 'Year', 'Internet_Users_Pct']
internet_df
# Out:
#           Country  Year  Internet_Users_Pct
# 0     Afghanistan  2014            6.390000
# 1     Afghanistan  2013            5.900000
# 2     Afghanistan  2012            5.454545
# 3     Afghanistan  2011            5.000000
# 4     Afghanistan  2010            4.000000
# ...           ...   ...                 ...
# 4490     Zimbabwe  1997            0.033080
# 4491     Zimbabwe  1996            0.016790
# 4492     Zimbabwe  1995            0.007684
# 4493     Zimbabwe  1994            0.001739
# 4494     Zimbabwe  1990            0.000000
#
# [4495 rows x 3 columns]

# %% [markdown]
# ## MERGE

# %%
gdp_and_internet_use = pd.merge(gdp_df, internet_df, left_on = 'Country', 
                                right_on = 'Country', how = 'inner')
gdp_and_internet_use.head(5)
# Out:
#        Country  Year_x  GDP_Per_Capita  Year_y  Internet_Users_Pct
# 0  Afghanistan    2020     1970.560169    2014            6.390000
# 1  Afghanistan    2020     1970.560169    2013            5.900000
# 2  Afghanistan    2020     1970.560169    2012            5.454545
# 3  Afghanistan    2020     1970.560169    2011            5.000000
# 4  Afghanistan    2020     1970.560169    2010            4.000000

# %%
gdp_and_internet_use.tail(5)
# Out:
#          Country  Year_x  GDP_Per_Capita  Year_y  Internet_Users_Pct
# 108530  Zimbabwe    1990     2652.129209    1997            0.033080
# 108531  Zimbabwe    1990     2652.129209    1996            0.016790
# 108532  Zimbabwe    1990     2652.129209    1995            0.007684
# 108533  Zimbabwe    1990     2652.129209    1994            0.001739
# 108534  Zimbabwe    1990     2652.129209    1990            0.000000

# %%
combined_df = gdp_and_internet_use[
    (gdp_and_internet_use['Year_x']) == 
    (gdp_and_internet_use['Year_y'])]
combined_df.drop(columns='Year_y')
# Out:
#             Country  Year_x  GDP_Per_Capita  Internet_Users_Pct
# 90      Afghanistan    2014     2102.384604            6.390000
# 106     Afghanistan    2013     2116.465258            5.900000
# 122     Afghanistan    2012     2075.491614            5.454545
# 138     Afghanistan    2011     1904.559926            5.000000
# 154     Afghanistan    2010     1957.029070            4.000000
# ...             ...     ...             ...                 ...
# 108376     Zimbabwe    1997     2856.118188            0.033080
# 108399     Zimbabwe    1996     2808.558556            0.016790
# 108422     Zimbabwe    1995     2573.993785            0.007684
# 108445     Zimbabwe    1994     2603.927369            0.001739
# 108534     Zimbabwe    1990     2652.129209            0.000000
#
# [3415 rows x 4 columns]

# %%
combined_df = combined_df[(combined_df['Year_x'] == 2004) | 
                          (combined_df['Year_x'] == 2009) 
                          | (combined_df['Year_x'] == 2014)]
combined_df = combined_df.rename(columns = {'Year_x':'Year'})
combined_df
# Out:
#             Country  Year  GDP_Per_Capita  Year_y  Internet_Users_Pct
# 90      Afghanistan  2014     2102.384604    2014            6.390000
# 170     Afghanistan  2009     1758.904477    2009            3.550000
# 250     Afghanistan  2004     1200.278013    2004            0.105809
# 411         Albania  2014    11586.833878    2014           60.100000
# 521         Albania  2009    10313.916338    2009           41.200000
# ...             ...   ...             ...     ...                 ...
# 107418       Zambia  2009     2917.515557    2009            6.310000
# 107533       Zambia  2004     2261.766733    2004            2.013550
# 107985     Zimbabwe  2014     2357.651166    2014           19.890000
# 108100     Zimbabwe  2009     1536.033715    2009           11.360000
# 108215     Zimbabwe  2004     1979.200783    2004            6.564045
#
# [480 rows x 5 columns]

# %% [markdown]
# ## 2004, 2009, 2014 Data

# %%
year_2014 = combined_df[combined_df['Year'] == 2014]
year_2009 = combined_df[combined_df['Year'] == 2009]
year_2004 = combined_df[combined_df['Year'] == 2004]

# %% [markdown]
# ## Internet Users

# %%
year_2014.sort_values(by = 'Internet_Users_Pct', ascending = False)
# Out:
#            Country  Year  GDP_Per_Capita  Year_y  Internet_Users_Pct
# 44230      Iceland  2014    50450.741612    2014               98.16
# 11540      Bermuda  2014    77361.104881    2014               96.80
# 72450       Norway  2014    62390.130313    2014               96.30
# 27281      Denmark  2014    52048.335493    2014               95.99
# 56582   Luxembourg  2014   113313.578898    2014               94.67
# ...            ...   ...             ...     ...                 ...
# 71180        Niger  2014     1126.805440    2014                1.95
# 40486       Guinea  2014     2061.694838    2014                1.72
# 89102      Somalia  2014      917.876549    2014                1.63
# 17389      Burundi  2014      886.235296    2014                1.38
# 97367  Timor-Leste  2014     3266.731666    2014                1.14
#
# [163 rows x 5 columns]

# %% [markdown]
# ## - 2014 Highest and Lowest
# Highest: Iceland (98.16%)
# Lowest: Timor-Leste (1.14%)

# %%
year_2009.sort_values(by = 'Internet_Users_Pct', ascending = False)
# Out:
#             Country  Year  GDP_Per_Capita  Year_y  Internet_Users_Pct
# 44360       Iceland  2009    48770.950337    2009           93.000000
# 72580        Norway  2009    61689.558543    2009           92.080000
# 93545        Sweden  2009    45492.768175    2009           91.000000
# 69139   Netherlands  2009    51607.605727    2009           89.630000
# 56707    Luxembourg  2009   112230.081410    2009           87.310000
# ...             ...   ...             ...     ...                 ...
# 32220      Ethiopia  2009     1150.206044    2009            0.540000
# 18678      Cambodia  2009     2603.583593    2009            0.530000
# 85836  Sierra Leone  2009     1365.218902    2009            0.260000
# 67036       Myanmar  2009     2527.390561    2009            0.220000
# 97432   Timor-Leste  2009     2729.281474    2009            0.185252
#
# [161 rows x 5 columns]

# %% [markdown]
# ## - 2009 Highest and Lowest
# Highest: Iceland (93.00%)
# Lowest: Timor-Leste (0.185%)

# %%
year_2004.sort_values(by = 'Internet_Users_Pct', ascending = False)
# Out:
#            Country  Year  GDP_Per_Capita  Year_y  Internet_Users_Pct
# 93675       Sweden  2004    44354.391062    2004           83.890000
# 44490      Iceland  2004    46051.743888    2004           83.880000
# 27541      Denmark  2004    50446.541605    2004           80.930000
# 72710       Norway  2004    60699.566582    2004           77.690000
# 33758      Finland  2004    43724.966123    2004           72.390000
# ...            ...   ...             ...     ...                 ...
# 32330     Ethiopia  2004      793.093753    2004            0.155335
# 250    Afghanistan  2004     1200.278013    2004            0.105809
# 95097   Tajikistan  2004     1837.331120    2004            0.077480
# 55489      Liberia  2004     1219.414000    2004            0.031011
# 67121      Myanmar  2004     1473.020996    2004            0.024337
#
# [156 rows x 5 columns]

# %% [markdown]
# ## - 2004 Highest and Lowest
# Highest: Sweden (83.89%)
# Lowest: Myanmar (0.024%)

# %% [markdown]
# ## 2014 GDP

# %%
year_2014.sort_values(by = 'GDP_Per_Capita', ascending = False)
# Out:
#            Country  Year  GDP_Per_Capita  Year_y  Internet_Users_Pct
# 56582   Luxembourg  2014   113313.578898    2014               94.67
# 80043        Qatar  2014    95578.261511    2014               91.49
# 86441    Singapore  2014    87616.637527    2014               82.00
# 11540      Bermuda  2014    77361.104881    2014               96.80
# 94190  Switzerland  2014    67682.686175    2014               87.00
# ...            ...   ...             ...     ...                 ...
# 57916       Malawi  2014     1457.473020    2014                5.83
# 66355   Mozambique  2014     1217.088867    2014                5.94
# 71180        Niger  2014     1126.805440    2014                1.95
# 89102      Somalia  2014      917.876549    2014                1.63
# 17389      Burundi  2014      886.235296    2014                1.38
#
# [163 rows x 5 columns]

# %% [markdown]
# ## - 2014 Highest and Lowest
# Highest: Luxembourg (113313.57)
# Lowest: Burundi (886.23)

# %% [markdown]
# ## Scatter Plots

# %%
x_2014 = year_2014['GDP_Per_Capita']
x_2009 = year_2009['GDP_Per_Capita']
x_2004 = year_2004['GDP_Per_Capita']

y_2014 = year_2014['Internet_Users_Pct']
y_2009 = year_2009['Internet_Users_Pct']
y_2004 = year_2004['Internet_Users_Pct']

plt.scatter(x_2014, y_2014, s=5, color = 'blue')
plt.scatter(x_2009, y_2009, s=5, color = 'red')
plt.scatter(x_2004, y_2004, s=5, color = 'green')

plt.ylabel('Internet Users (% of population)')
plt.xlabel('GDP Per Capita (USD)')
plt.title('Internet Users by percentage By GDP per capita per nation')
plt.legend(['2014', '2009', '2004'])

# %% [markdown]
# As time progresses, larger percentages of national populations are able to access the internet with a lower national GDP per capita than in previous years. Additionally the trend lines for all three years are monotone; an increase in GDP corresponds to an increase in percent of internet users
